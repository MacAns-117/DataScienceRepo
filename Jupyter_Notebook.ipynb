# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM WatsonStudio

# %% [markdown]
# <b>Maqsood Ahmed Ansari</b>
# Fresh Post-Grad

# %% [markdown]
# <i>I am intrested in Data Science because i was fascinated by how the google assistant/ Cortana assistants work.</i>

# %% [markdown]
# ### The Following code adds two numbers and prints their sum

# %%
a = 3
b = 5
c = a + b
print(c)
# Out:
# 8

# %% [markdown]
# This is a Bulleted List:
# <ul>
# <li>Item 1</>
# <li>Item 2</>
# <li>Item 3</>
# </ul>
#
# <hr/>
#
# This is a Numbered List
# <ol>
# <li>Item 1</>
# <li>Item 2</>
# <li>Item 3</>
# </uo>
